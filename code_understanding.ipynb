# %% [markdown]
# # understanding

# %% [markdown]
# # AI Gesture Controlled System — Code Explanation
#
# # Project Overview
#
# This project is a real-time computer vision system that controls:
#
# - system brightness
# - system volume
#
# using hand gestures captured from a webcam.
#
# The project uses:
#
# - OpenCV
# - MediaPipe
# - NumPy
# - Pycaw
#
# The overall system pipeline is:
#
# ```text
# Webcam
# → Hand Detection
# → Landmark Extraction
# → Distance Calculation
# → Gesture Processing
# → Signal Smoothing
# → Dead-Zone Filtering
# → System Control
# ```
#
# ---
#
# # 1. Imports
#
# ```python
# import cv2
# import mediapipe as mp
# import numpy as np
# import math
# import os
# ```
#
# Imports are external libraries that provide extra functionality to Python.
#
# Without imports:
# - Python cannot access webcam
# - cannot perform AI hand tracking
# - cannot process images
# - cannot control brightness or volume
#
# ---
#
# # 2. OpenCV (cv2)
#
# ```python
# import cv2
# ```
#
# OpenCV is a computer vision library.
#
# It is used for:
#
# - accessing webcam
# - reading video frames
# - drawing shapes
# - displaying windows
# - image processing
#
# In this project OpenCV handles:
#
# - webcam feed
# - circles on fingertips
# - lines between fingers
# - text display
# - UI rendering
#
# Example:
#
# ```python
# cv2.circle()
# ```
#
# draws circles on fingertips.
#
# Example:
#
# ```python
# cv2.imshow()
# ```
#
# shows the webcam window.
#
# ---
#
# # 3. MediaPipe
#
# ```python
# import mediapipe as mp
# ```
#
# MediaPipe is Google's AI-based hand tracking framework.
#
# It detects:
#
# - hands
# - fingers
# - landmarks
#
# MediaPipe provides 21 hand landmarks.
#
# Examples:
#
# | Landmark | Meaning |
# |---|---|
# | 4 | Thumb tip |
# | 8 | Index finger tip |
# | 12 | Middle finger tip |
# | 20 | Pinky finger tip |
#
# These landmarks help the system understand hand gestures.
#
# Without MediaPipe:
# - the system cannot understand hands.
#
# ---
#
# # 4. NumPy
#
# ```python
# import numpy as np
# ```
#
# NumPy is a numerical computing library.
#
# It is used for:
#
# - calculations
# - interpolation
# - numerical operations
#
# Main use in this project:
#
# ```python
# np.interp()
# ```
#
# This converts:
#
# ```text
# finger distance
# → brightness percentage
# ```
#
# Example:
#
# ```text
# 20 pixels → 0%
# 200 pixels → 100%
# ```
#
# This mapping makes gesture control possible.
#
# ---
#
# # 5. Math Library
#
# ```python
# import math
# ```
#
# Used for mathematical operations.
#
# Main usage:
#
# ```python
# math.hypot()
# ```
#
# This calculates the distance between two points.
#
# Distance formula:
#
# ```math
# d = \sqrt{(x_2-x_1)^2 + (y_2-y_1)^2}
# ```
#
# In this project:
#
# - thumb tip position
# - index tip position
#
# are used to calculate finger distance.
#
# The distance controls:
# - brightness
# - volume
#
# ---
#
# # 6. OS Library
#
# ```python
# import os
# ```
#
# OS library helps Python interact with the operating system.
#
# Used for:
#
# - running PowerShell commands
# - controlling brightness
# - creating folders
#
# Example:
#
# ```python
# os.system()
# ```
#
# runs Windows commands directly from Python.
#
# ---
#
# # 7. MediaPipe Hand Tracking Pipeline
#
# The system works like this:
#
# ```text
# Camera Frame
# → MediaPipe Detection
# → Landmark Extraction
# → Gesture Analysis
# → System Control
# ```
#
# ---
#
# # 8. Webcam Capture
#
# ```python
# cap = cv2.VideoCapture(0)
# ```
#
# This opens the webcam.
#
# `0` means:
# - default webcam
#
# The webcam continuously captures frames.
#
# ---
#
# # 9. Reading Frames
#
# ```python
# success, frame = cap.read()
# ```
#
# This reads one image frame from the webcam.
#
# `frame` contains:
# - current webcam image
#
# The system processes frames continuously in a loop.
#
# ---
#
# # 10. Frame Mirroring
#
# ```python
# frame = cv2.flip(frame, 1)
# ```
#
# This flips the webcam horizontally.
#
# Reason:
#
# Without flipping:
# - movement feels opposite
#
# Mirroring makes interaction natural.
#
# ---
#
# # 11. BGR to RGB Conversion
#
# ```python
# rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ```
#
# OpenCV uses:
# - BGR color format
#
# MediaPipe requires:
# - RGB format
#
# So conversion is necessary.
#
# ---
#
# # 12. MediaPipe Image Conversion
#
# ```python
# mp_image = mp.Image(
#     image_format=mp.ImageFormat.SRGB,
#     data=rgb_frame
# )
# ```
#
# Converts OpenCV frame into MediaPipe format.
#
# This allows MediaPipe AI models to process the frame.
#
# ---
#
# # 13. Hand Detection
#
# ```python
# detection_result = detector.detect(mp_image)
# ```
#
# MediaPipe AI model analyzes the frame.
#
# It detects:
# - hands
# - finger landmarks
# - hand orientation
#
# ---
#
# # 14. Landmark Extraction
#
# ```python
# thumb_tip = hand_landmarks[4]
# index_tip = hand_landmarks[8]
# ```
#
# These lines extract fingertip positions.
#
# Landmark 4:
# - thumb tip
#
# Landmark 8:
# - index finger tip
#
# These points are used for gesture calculation.
#
# ---
#
# # 15. Coordinate Conversion
#
# ```python
# thumb_x = int(thumb_tip.x * w)
# thumb_y = int(thumb_tip.y * h)
# ```
#
# MediaPipe returns normalized coordinates:
#
# ```text
# 0 → 1
# ```
#
# They must be converted into screen pixels.
#
# ---
#
# # 16. Drawing UI
#
# ```python
# cv2.circle()
# cv2.line()
# cv2.putText()
# ```
#
# These functions create visual overlays.
#
# Used for:
# - fingertip circles
# - connection lines
# - labels
# - percentages
#
# This creates the interactive UI.
#
# ---
#
# # 17. Distance Calculation
#
# ```python
# distance = math.hypot(
#     x2 - x1,
#     y2 - y1
# )
# ```
#
# Calculates distance between thumb and index finger.
#
# This distance becomes the gesture signal.
#
# Small distance:
# - low brightness/volume
#
# Large distance:
# - high brightness/volume
#
# ---
#
# # 18. Smoothing System
#
# ```python
# smooth_distance = (
#     alpha * current
#     + (1 - alpha) * previous
# )
# ```
#
# This is Exponential Moving Average (EMA) smoothing.
#
# Purpose:
# - reduce jitter
# - stabilize movement
# - remove noise
#
# Without smoothing:
# - controls flicker rapidly
#
# With smoothing:
# - movement becomes stable
#
# ---
#
# # 19. Dead-Zone Filtering
#
# ```python
# if abs(current - previous) > dead_zone:
# ```
#
# Small accidental movements are ignored.
#
# Purpose:
# - prevent unnecessary updates
# - reduce shaking
# - improve stability
#
# Without dead-zone:
# - tiny movement constantly changes brightness/volume
#
# ---
#
# # 20. Brightness Mapping
#
# ```python
# brightness = np.interp(
#     distance,
#     [20, 200],
#     [0, 100]
# )
# ```
#
# Converts finger distance into brightness percentage.
#
# Example:
#
# | Distance | Brightness |
# |---|---|
# | 20 | 0% |
# | 200 | 100% |
#
# ---
#
# # 21. Volume Mapping
#
# ```python
# volume.SetMasterVolumeLevelScalar()
# ```
#
# Controls system volume.
#
# Finger distance determines:
# - volume percentage
#
# ---
#
# # 22. Real-Time Loop
#
# ```python
# while True:
# ```
#
# This continuously runs the system.
#
# Every frame:
# - webcam updates
# - AI detects hands
# - gestures processed
# - system controls updated
#
# ---
#
# # 23. Exit System
#
# ```python
# if cv2.waitKey(1) & 0xFF == ord('q'):
# ```
#
# Pressing:
# ```text
# q
# ```
#
# closes the application safely.
#
# ---
#
# # 24. Final Architecture Summary
#
# The final system pipeline:
#
# ```text
# Webcam Input
# → Frame Processing
# → AI Hand Detection
# → Landmark Extraction
# → Distance Calculation
# → Smoothing
# → Dead-Zone Filtering
# → Brightness/Volume Mapping
# → System Control
# → UI Rendering
# ```
#
# ---
#
# # 25. Engineering Concepts Used
#
# This project demonstrates:
#
# - Computer Vision
# - Real-Time Processing
# - Human Computer Interaction (HCI)
# - Signal Smoothing
# - Noise Reduction
# - Gesture Recognition
# - System Automation
# - AI-Based Hand Tracking
#
# ---
#
# # 26. Libraries Used
#
# | Library | Purpose |
# |---|---|
# | OpenCV | Webcam and UI |
# | MediaPipe | AI hand tracking |
# | NumPy | Numerical calculations |
# | Math | Distance calculation |
# | Pycaw | Volume control |
# | OS | System commands |
#
# ---
#
# # 27. Key Learning Outcomes
#
# Through this project the following concepts were learned:
#
# - webcam frame processing
# - AI hand landmark detection
# - gesture recognition
# - coordinate mapping
# - real-time UI rendering
# - smoothing filters
# - dead-zone filtering
# - system automation
# - brightness and volume control
